# %% [markdown]
# # Python Programming: Missing Data Imputation

# %% [markdown]
# ## Complete Case Analysis

# %%
## Example: Part 1
# ---
# Delete observations where any of the variable is missing
# 

import numpy as np
import pandas as pd

raw_data = {'first_name': ['John', np.nan, 'Tina', 'Visic', 'Alex'], 
        'last_name': ['Salah', np.nan, 'Abraham', 'John', 'Kate'], 
        'age': [32, np.nan, 26, 26, 74], 
        'sex': ['m', np.nan, 'f', 'm', 'f'], 
        'preSAT': [14, np.nan, np.nan, 22, 13],
        'postSAT': [27, np.nan, np.nan, 52, 71]}

df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'sex', 'preSAT', 'postSAT'])
df

# %%
## Example: Part 2
# ---
df_no_missing = df.dropna()
df_no_missing

# %%
## Challenge 
# ---
# Perform complete case analysis on the following dataset
# ---
# Dataset url = http://bit.ly/TitanicMissingData
# 
OUR CODE GOES HERE

# %% [markdown]
# ## Mean / Median / Mode imputation

# %%
## Example: Part 1
# ---
# Mean / Median / Mode imputation replaces missing values 
# with the mean / median / mode  value of that feature/variable.
# ---
# 

# Create an empty dataset
df = pd.DataFrame()

# Create two variables called x0 and x1. Make the first value of x1 a missing value
df['x0'] = [0.3051,0.4949,0.6974,0.3769,0.2231,0.341,0.4436,0.5897,0.6308,0.5]
df['x1'] = [np.nan,0.2654,0.2615,0.5846,0.4615,0.8308,0.4962,0.3269,0.5346,0.6731]

# View the dataset
df

# %%
## Example: Part 2
# ---
# 
from sklearn.impute import SimpleImputer

# Create an imputer object that looks for 'Nan' values, then replaces them with the mean value of the feature by columns 
imp_mean = SimpleImputer(missing_values='NaN', strategy='mean')

# Train the imputor on the df dataset
mean_imputer = mean_imputer.fit(df)

# Apply the imputer to the df dataset
imputed_df = mean_imputer.transform(df.values)

# View the data
print(imputed_df)

# %%
## Challenge 
# ---
# By using your understandin on the above examples, perform imputation by median and mode.
# Documentation: https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html
# ---
# 
OUR CODE GOES HERE
