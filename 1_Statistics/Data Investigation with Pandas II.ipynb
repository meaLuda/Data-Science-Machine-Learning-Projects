# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # Data Investigation with Pandas II

# %% [markdown]
# ## 1.0 Importing our Libraries

# %%
# Importing the libraries we will need 

# Importing the pandas library
# 
import pandas as pd

# Importing the numpy library
#
import numpy as np

# %% [markdown]
# ## 1.1 Reading the Dataset from our CSV file

# %% [markdown]
# This dataset contains trips taken by thousands of kenyans to and from Nairobi during the year 2018.
#
# *   Dataset link for download or access: [Link](https://drive.google.com/a/moringaschool.com/file/d/1xe2sHapdeGo7bIaiG7UV0rjgQZ5U6OXv/view?usp=sharing)

# %%
# Let's read the data from the CSV file and create the dataframe to be used
# 
with open('bus_travels.csv','r') as b:
  df = pd.read_csv(b, index_col=0, encoding='UTF-8')

# %% [markdown]
# ## 1.2 Previewing our Dataset

# %%
# Let's preview the first 10 rows of our data
# 
df[:10]
# Out:
#         travel_date travel_time travel_from travel_to car_type  max_capacity
# ride_id
# 247      2018-05-07       07:06       Kisii   Nairobi      Bus            49
# 256      2018-05-06       11:08       Kisii   Nairobi  shuttle            11
# 275      2018-05-04       05:00       Kisii   Nairobi  shuttle            11
# 285      2018-05-04       09:10       Kisii   Nairobi  shuttle            11
# 286      2018-05-04       09:20       Kisii   Nairobi  shuttle            11
# 287      2018-05-04       07:02       Kisii   Nairobi      Bus            49
# 288      2018-05-04       09:30       Kisii   Nairobi  shuttle            11
# 292      2018-05-04       19:03       Kisii   Nairobi      Bus            49
# 298      2018-05-04       09:00       Kisii   Nairobi  shuttle            11
# 302      2018-05-04       08:40       Kisii   Nairobi  shuttle            11

# %% [markdown]
# ## 1.3 Accessing Information about our Dataset

# %%
# Getting to know more about the dataset by accessing its information
#
df.describe
# Out:
# <bound method NDFrame.describe of         travel_date travel_time travel_from travel_to car_type  max_capacity
# ride_id
# 247      2018-05-07       07:06       Kisii   Nairobi      Bus            49
# 256      2018-05-06       11:08       Kisii   Nairobi  shuttle            11
# 275      2018-05-04       05:00       Kisii   Nairobi  shuttle            11
# 285      2018-05-04       09:10       Kisii   Nairobi  shuttle            11
# 286      2018-05-04       09:20       Kisii   Nairobi  shuttle            11
# ...             ...         ...         ...       ...      ...           ...
# 15336    2018-05-07       07:01      Oyugis   Nairobi      Bus            49
# 15337    2018-05-07       07:08    Kehancha   Nairobi      Bus            49
# 15338    2018-05-07       07:04       Rongo   Nairobi      Bus            49
# 15339    2018-05-07       07:05      Ndhiwa   Nairobi      Bus            49
# 15344    2018-05-09       08:00      Migori   Nairobi      Bus            49
#
# [1111 rows x 6 columns]>

# %% [markdown]
# ## 1.4 Answering Questions

# %% [markdown]
# Let's answer the following questions with our dataset

# %%
df[['travel_date','travel_from','travel_to']].head()
# Out:
#         travel_date travel_from travel_to
# ride_id
# 247      2018-05-07       Kisii   Nairobi
# 256      2018-05-06       Kisii   Nairobi
# 275      2018-05-04       Kisii   Nairobi
# 285      2018-05-04       Kisii   Nairobi
# 286      2018-05-04       Kisii   Nairobi

# %%
# Challenge 1
# How many trips were taken on the 22/04/18?
# 
trips = df.loc[(df['travel_date'].values == '2018-04-22')]

trips_taken = trips[['travel_from','travel_to']].count().sum()

# %%
# Challenge 2
# Which type of vehicle travelled on 23/04/18 from Kisii to Nairobi at 7.15am?
#
vehicles = df.loc[(df['travel_date'].values == '2018-04-23') & (df['travel_time'] == '07:15')]
vehicles[['travel_date','car_type']]
# Out:
#         travel_date car_type
# ride_id
# 5676     2018-04-23  shuttle

# %%
# Challenge 3
# How many trips were made from Kisii to Nairobi?
# 
trips_k_n = df.loc[(df['travel_from'] == 'Kisii') & (df['travel_to'] == 'Nairobi')]
trips_k_n.count().sum()
# Out:
# 3270

# %%
# Challenge 4
# How many trips were made by shuttle from Nairobi?
# 
shuttle_trip = df.loc[(df['car_type'] == 'shuttle') & (df['travel_from'] == 'Nairobi') ]
shuttle_trip.count().sum()
# Out:
# 0

# %%
# Challenge 5
# How many trips were made by bus from Nairobi to Awendo?
# 
trips_n_a = df.loc[(df['car_type'] == 'Bus') & (df['travel_from'] == 'Nairobi') ]
trips_n_a.count()
# Out:
# travel_date     0
# travel_time     0
# travel_from     0
# travel_to       0
# car_type        0
# max_capacity    0
# dtype: int64

# %%
# Challenge 5
# How many trips were made by bus from Nairobi to Awendo?
# 
trips_n_a = df.loc[(df['car_type'] == 'Bus') & (df['travel_from'] == 'Awendo') ]
trips_n_a.count().sum()
# Out:
# 264

# %%
# Challenge 6
# Which was the most travelled from destination by bus?
# 
most_bus_travel = df.loc[(df['car_type'] == 'Bus')]
most_bus_travel.sort_values(by=['travel_from','travel_to'], ascending=False)
# Out:
#         travel_date travel_time travel_from travel_to car_type  max_capacity
# ride_id
# 13854    2018-04-21       23:10        Sori   Nairobi      Bus            49
# 13901    2018-04-22       23:10        Sori   Nairobi      Bus            49
# 13936    2018-04-22       07:05        Sori   Nairobi      Bus            49
# 13988    2018-04-23       23:10        Sori   Nairobi      Bus            49
# 14023    2018-04-23       07:05        Sori   Nairobi      Bus            49
# ...             ...         ...         ...       ...      ...           ...
# 15122    2018-05-03       07:13      Awendo   Nairobi      Bus            49
# 15176    2018-05-03       06:59      Awendo   Nairobi      Bus            49
# 15185    2018-05-03       07:08      Awendo   Nairobi      Bus            49
# 15268    2018-05-04       07:08      Awendo   Nairobi      Bus            49
# 15304    2018-05-05       07:13      Awendo   Nairobi      Bus            49
#
# [599 rows x 6 columns]

# %%
# Challenge 7
# Which was the most travelled to destination?
# 
travel_to = df['travel_to']
travel_to.describe()
# Out:
# count        1111
# unique          1
# top       Nairobi
# freq         1111
# Name: travel_to, dtype: object

# %%
with open('bus_travels.csv','r') as b:
  df = pd.read_csv(b, index_col=0, encoding='UTF-8')

# %%
# Challenge 8
# Which was the most travelled destination by bus?
# 
most_t = df.loc[(df['car_type'] == 'Bus')]
most_t[['travel_to']].describe()
# Out:
#        travel_to
# count        599
# unique         1
# top      Nairobi
# freq         599

# %%
# Challenge 9
# Which town did not have a departure by shuttle?
# 
not_shttl = df.loc[(df['car_type'] != 'shuttle')]

not_shttl[['travel_from']].describe()
# Out:
#        travel_from
# count          599
# unique          15
# top          Rongo
# freq           115

# %%
# Challenge 10
# Which were the most 5 travelled to destinations?
# 
t_to = df['travel_to']
t_to.max()
# Out:
# 'Nairobi'

# %%
# Challenge 11
# Which were the least 5 travelled to destinations?
#
t_to.min()
# Out:
# 'Nairobi'

# %%
df
# Out:
#         travel_date travel_time travel_from travel_to car_type  max_capacity
# ride_id
# 247      2018-05-07       07:06       Kisii   Nairobi      Bus            49
# 256      2018-05-06       11:08       Kisii   Nairobi  shuttle            11
# 275      2018-05-04       05:00       Kisii   Nairobi  shuttle            11
# 285      2018-05-04       09:10       Kisii   Nairobi  shuttle            11
# 286      2018-05-04       09:20       Kisii   Nairobi  shuttle            11
# ...             ...         ...         ...       ...      ...           ...
# 15336    2018-05-07       07:01      Oyugis   Nairobi      Bus            49
# 15337    2018-05-07       07:08    Kehancha   Nairobi      Bus            49
# 15338    2018-05-07       07:04       Rongo   Nairobi      Bus            49
# 15339    2018-05-07       07:05      Ndhiwa   Nairobi      Bus            49
# 15344    2018-05-09       08:00      Migori   Nairobi      Bus            49
#
# [1111 rows x 6 columns]

# %%
# Challenge 12
# If all shuttles travelled with full capacity, how many people travelled in shuttles from Kisii to Nairobi in the month of May?
#

df['travel_date'] = pd.to_datetime(df['travel_date'])
#df.info()

may  = df[df['travel_date'].dt.month == 5]

#people = df[(df['travel_from']== 'Kisii') & (df['travel_to'] == 'Nairobi') & (may)]


df[(df['travel_from'] == 'Kisii') & (df['travel_to'] == 'Nairobi') & (df['car_type'] == 'shuttle') & ( df['travel_date'].dt.month == 5)]['ride_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ride_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-1e99c1a642af> in <module>()
#      11
#      12
# ---> 13 df[(df['travel_from'] == 'Kisii') & (df['travel_to'] == 'Nairobi') & (df['car_type'] == 'shuttle') & ( df['travel_date'].dt.month == 5)]['ride_id']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'ride_id'

# %%
# Challenge 13
# Which date had the highest no. of trips in June?
#

# %%
# Challenge 14
# On average, how many trips were made by all vehicles in a day?
#

# %%
# Challenge 15 
# On average, how many buses and shuttles travelled in a day?
#
