# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # SQL Data Analysis: Population by Type of Disability

# %% [markdown]
# ## 1.0 Connecting to our Database

# %%
# We will first load the sql extension into our environment
# %load_ext sql

# Then connect to our in memory sqlite database
# NB: This database will cease to exist as soon as the database connection is closed. 
# %sql sqlite://
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: @None'

# %% [markdown]
# ## 1.1 Importing Data from CSV files

# %%
# Importing the pandas library
# We will use a function read_csv from pandas to read our datasets as shown
#
import pandas as pd

# %%
# Loading our table from the respective CSV files
# We will export the dataset that we have cleaned using python
#
with open('example.csv','r') as f:
    Population = pd.read_csv(f, index_col=0, encoding='utf-8')
    
# %sql DROP TABLE if EXISTS Population;
# %sql PERSIST Population;
# %sql SELECT * FROM Population LIMIT 5;
# Out:
#  * sqlite://
# Done.
#  * sqlite://
#  * sqlite://
# Done.
# [('Baringo', 10.9, 2.8, 30.9, 2.6, 1.0, 3.8, 12.4, 54.2, 10.9, 6512.1, 0),
#  ('Bomet', 0.0, 0.0, 29.2, 10.0, 8.1, 8.1, 14.2, 0.3, 38.7, 6538.0, 1),
#  ('Bungoma', 12.3, 0.0, 49.2, 0.0, 2.3, 20.8, 12.7, 0.0, 21.9, 13170.6, 2),
#  ('Busia', 0.0, 0.0, 14.3, 12.3, 4.6, 35.5, 4.8, 14.8, 31.4, 6655.5, 3),
#  ('Elgeyo Marakwet', 0.0, 0.0, 31.7, 0.0, 35.7, 0.0, 20.0, 12.6, 7.4, 3599.9, 4)]

# %% [markdown]
# ## 1.2 Previewing our Dataset

# %%
# Let's preview the first 10 rows of our data
# 
# %%sql
SELECT * FROM Population limit 10;
# Out:
#  * sqlite://
# Done.
# [('Baringo', 10.9, 2.8, 30.9, 2.6, 1.0, 3.8, 12.4, 54.2, 10.9, 6512.1, 0),
#  ('Bomet', 0.0, 0.0, 29.2, 10.0, 8.1, 8.1, 14.2, 0.3, 38.7, 6538.0, 1),
#  ('Bungoma', 12.3, 0.0, 49.2, 0.0, 2.3, 20.8, 12.7, 0.0, 21.9, 13170.6, 2),
#  ('Busia', 0.0, 0.0, 14.3, 12.3, 4.6, 35.5, 4.8, 14.8, 31.4, 6655.5, 3),
#  ('Elgeyo Marakwet', 0.0, 0.0, 31.7, 0.0, 35.7, 0.0, 20.0, 12.6, 7.4, 3599.9, 4)]

# %% [markdown]
# ## 1.3 Accessing Information about our Dataset

# %%
# Getting to know more about the dataset by accessing its information
#
# %%sql
DESCRIBE Population;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) near "DESCRIBE": syntax error
# [SQL: DESCRIBE Population;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## 1.5 Answering Questions

# %% [markdown]
# Let's answer the following questions with our dataset. These are the same questions we answered using the python programming language.

# %%
# Challenge 1
# Which county had the highest no. of registered deaf persons?
# 
# %%sql
SELECT county, MAX(deaf) FROM Population;
# Out:
#  * sqlite://
# Done.
# [('Elgeyo Marakwet', 35.7)]

# %%
# Challenge 2
# Which county had the highest no. of registered persons with a missing hand?
# %%sql
SELECT county, MAX(missinghand) FROM Population;
# Out:
#  * sqlite://
# Done.
# [('Bungoma', 12.3)]

# %%
# Challenge 3
# Which county had the highest no. of registered persons with a missing foot?
# 
# %%sql
SELECT county, MAX(missingfoot) FROM Population;
# Out:
#  * sqlite://
# Done.
# [('Baringo', 2.8)]

# %%
# Challenge 4
# Which county had the highest no. of registered lame persons?
# 
# %%sql
SELECT county, MAX(lame) FROM Population;
# Out:
#  * sqlite://
# Done.
# [('Bungoma', 49.2)]

# %%
# Challenge 5
# Which county had the lowest no. of registered blind persons?
# 
# %%sql
SELECT county, MAX(deaf) FROM Population;
# Out:
#  * sqlite://
# Done.
# [('Elgeyo Marakwet', 35.7)]

# %%
# Challenge 6
# Which county had the highest third no. of registered deaf persons?
# 
# %%sql
SELECT county, deaf FROM Population 
ORDER BY deaf DESC ;
# Out:
#  * sqlite://
# Done.
# [('Elgeyo Marakwet', 35.7),
#  ('Bomet', 8.1),
#  ('Busia', 4.6),
#  ('Bungoma', 2.3),
#  ('Baringo', 1.0)]

# %%
# Challenge 7
# In descending order, which top 5 counties had the highest no. of registered dumb persons?
# 
# %%sql
SELECT county, dumb FROM Population 
ORDER BY dumb DESC LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [('Busia', 35.5),
#  ('Bungoma', 20.8),
#  ('Bomet', 8.1),
#  ('Baringo', 3.8),
#  ('Elgeyo Marakwet', 0.0)]

# %%
# Challenge 8
# In ascending order, which top 5 counties had the highest no. of registered persons with a mental disability? 
# 
# %%sql
SELECT county, mental FROM Population 
ORDER BY mental DESC LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [('Elgeyo Marakwet', 20.0),
#  ('Bomet', 14.2),
#  ('Bungoma', 12.7),
#  ('Baringo', 12.4),
#  ('Busia', 4.8)]

# %%
# Challenge 9
# Which counties had no registerd blind persons nor deaf persons?
# 
# %%sql
SELECT county, blind, deaf FROM Population 
WHERE deaf = 0 OR blind=0
# Out:
#  * sqlite://
# Done.
# [('Bungoma', 0.0, 2.3), ('Elgeyo Marakwet', 0.0, 35.7)]

# %%
# Challenge 10
# Which disability was the most registered across all the counties?
# 
# %%sql
SELECT county,MAX(missinghand),MAX(missingfoot),MAX(lame),MAX(blind),MAX(deaf),MAX(dumb),MAX(mental),MAX(paralyzed) FROM Population
# Out:
#  * sqlite://
# Done.
# [('Baringo', 12.3, 2.8, 49.2, 12.3, 35.7, 35.5, 20.0, 54.2)]

# %%
# Challenge 11
# Which disability was the least registered across all the counties?
#
# %%sql
SELECT county,MIN(missinghand),MIN(missingfoot),MIN(lame),MIN(blind),MIN(deaf),MIN(dumb),MIN(mental),MIN(paralyzed) FROM Population
# Out:
#  * sqlite://
# Done.
# [('Bungoma', 0.0, 0.0, 14.3, 0.0, 1.0, 0.0, 4.8, 0.0)]

# %%
# Challenge 12
# What was the average no. of registered persons with a disability?
#
# %%sql
SELECT county,AVG(missinghand),AVG(missingfoot),AVG(lame),AVG(blind),AVG(deaf),AVG(dumb),AVG(mental),AVG(paralyzed) FROM Population
# Out:
#  * sqlite://
# Done.
# [('Elgeyo Marakwet', 4.640000000000001, 0.5599999999999999, 31.059999999999995, 4.9799999999999995, 10.34, 13.64, 12.819999999999999, 16.38)]

# %%
# Challenge 13
# Which three counties had least registered persons with disabilities?
#
# %%sql
SELECT county FROM Population
WHERE (SELECT MIN(missinghand),MIN(missingfoot),MIN(lame),MIN(blind),MIN(deaf),MIN(dumb),MIN(mental),MIN(paralyzed) FROM Population)
# Out:
#  * sqlite://
# (sqlite3.OperationalError) sub-select returns 8 columns - expected 1
# [SQL: SELECT county FROM Population
# WHERE (SELECT MIN(missinghand),MIN(missingfoot),MIN(lame),MIN(blind),MIN(deaf),MIN(dumb),MIN(mental),MIN(paralyzed) FROM Population)]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# Challenge 14
# What was the total no of registered persons with a disability across all counties?
#
# %%sql
SELECT SUM(totalcount) FROM Population
# Out:
#  * sqlite://
# Done.
# [(36476.1,)]

# %%
# Challenge 15 
# Which top 3 counties has the highest no. of registered persons with a disability?
# 
# %%sql
SELECT county, totalcount FROM Population
ORDER BY totalcount DESC LIMIT 3;
# Out:
#  * sqlite://
# Done.
# [('Bungoma', 13170.6), ('Busia', 6655.5), ('Bomet', 6538.0)]
