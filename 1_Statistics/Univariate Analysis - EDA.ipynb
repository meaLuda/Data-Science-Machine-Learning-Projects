# %% [markdown]
# # Exploratory Data Analysis: Univariate Analysis

# %% [markdown]
# ## 1. Defining the Question

# %% [markdown]
# ### a) Specifying the Question

# %% [markdown]
# > How can a US insurance company determine the top 10 cities where its clients have the highest annual income for persons aged 40 and below?

# %% [markdown]
# ### b) Defining the Metric for Success
#
# > Determine top 10 Cities in US with highest annual income for persons aged 40 and below

# %% [markdown]
# ### c) Understanding the context
#
# > An insuarance company wants to find which cities have the highset annual income for persons aged 40 and below

# %% [markdown]
# ### d) Recording the Experimental Design

# %% [markdown]
# ### e) Data Relevance

# %% [markdown]
# ## 2. Reading the Data

# %%
# Loading the Data from the source i.e. csv
# Dataset url = http://bit.ly/MedicalCitiesIncomeDataset
#
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %%
dt_ld = pd.read_csv(r'C:\Users\munya\Desktop\DS\data\toy_dataset.csv')

# %%
df = dt_ld.copy()

# %% [markdown]
# ## 3. Checking the Data

# %%
# Determining the no. of records in our dataset
# (rows,columns)
df.shape
# Out:
# (150000, 6)

# %%
# Previewing the top of our dataset
#
df.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %%
# Previewing the bottom of our dataset
# 
df.tail()
# Out:
#         Number    City  Gender  Age    Income Illness
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No

# %%
# Checking whether each column has an appropriate datatype
#
df.dtypes
# Out:
# Number       int64
# City        object
# Gender      object
# Age          int64
# Income     float64
# Illness     object
# dtype: object

# %%
print(df.nunique())
# Out:
# Number     150000
# City            8
# Gender          2
# Age            41
# Income      71761
# Illness         2
# dtype: int64

# %%
df.columns
# Out:
# Index(['Number', 'City', 'Gender', 'Age', 'Income', 'Illness'], dtype='object')

# %% [markdown]
# ## 4. External Data Source Validation

# %% [markdown]
# Making sure your data matches something outside of the dataset is very important. It allows you to ensure that the measurements are roughly in line with what they should be and it serves as a check on what other things might be wrong in your dataset. External validation can often be as simple as checking your data against a single number, as we will do here.
#
# An example would be suppose that you're working with a dataset on the population of countries during the year 2016. Validating such information with an external reliable resource such as World Bank Data would be important step to providing credibility to your dataset. Have a look at the following link for an example. [Link](https://rstudio-pubs-static.s3.amazonaws.com/182250_19977d0c5c06403fbad1e653850fc7c6.html).

# %% [markdown]
# ### a.Validation

# %% [markdown]
# ## 5. Tidying the Dataset

# %%
# Checking for Outliers
#
col_names = ['Number','Age', 'Income']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):

    sns.boxplot(y=df[col_val], ax=ax[i])
    ax[i].set_title('Box plot - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
# Checking for Anomalies
#
col_names = ['Number','Age', 'Income']

sns.histplot(df.Income.dropna(), kde=True, bins = 39);

# %%
# Identifying the Missing Data
#
df.isnull().values.any()
# Out:
# False

# %%
# Dealing with the Missing Data
#

# %%
# More data cleaning procedures
#

# %% [markdown]
# ## 6. Exploratory Analysis

# %%
# Ploting the univariate summaries and recording our observations
#

# %%
sns.pairplot(df)

# %%
# scatter plot
sns.relplot(x='Age', y='Income', hue='Number', data=df)

# %%
sns.displot(df['Income'],bins=20)

# %%
sns.displot(df['Age'],bins=20)

# %%
sns.catplot(x='Income',kind='box',data=df)

# %% [markdown]
# ## 7. Implementing the Solution

# %%
df.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %%
df['City'].unique()
# Out:
# array(['Dallas', 'New York City', 'Los Angeles', 'Mountain View',
#        'Boston', 'Washington D.C.', 'San Diego', 'Austin'], dtype=object)

# %%
# Get where people are aged 40 <
df_new = df[ (df['Age'] <= 40) ]
df_new.reset_index(inplace=True,drop=True)

# %%
mean_income = df_new[['Income']].mean()

print(mean_income)
# Out:
# Income    91332.803502
# dtype: float64

# %%
df_new.head()
# Out:
#    Number    City  Gender  Age   Income Illness
# 0       4  Dallas    Male   40  40941.0      No
# 1       6  Dallas  Female   36  50786.0      No
# 2       7  Dallas  Female   32  33155.0      No
# 3       8  Dallas    Male   39  30914.0      No
# 4      10  Dallas  Female   30  50082.0      No

# %%
# Implementing the Solution
# Get incomes > 90,000
df_final = df_new[ (df_new['Income'] > 90000) ]
df_final.reset_index(inplace=True,drop=True)

print("\n Cities with highest Income per person aged 40 and below\n")
print(df_final['City'].unique())
# Out:
#  Cities with highest Income per person aged 40 and below
#
# ['New York City' 'Los Angeles' 'Mountain View' 'Boston' 'Washington D.C.'
#  'San Diego' 'Austin']
